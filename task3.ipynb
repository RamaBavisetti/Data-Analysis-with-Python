# %%
import pandas as pd
df=pd.read_csv("UScomments.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("UScomments.csv")
#       3 df
#
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "UScomments.csv",
    on_bad_lines='skip',           # Skip rows with errors
    quoting=1,                     # Handle quoted fields properly (QUOTE_ALL)
    encoding='utf-8',              # Ensure proper character decoding
    low_memory=False               # Prevent dtype guessing errors
)

print(df.head())
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.isnull()
# Out:
#         video_id  comment_text  likes  replies
# 0          False         False  False    False
# 1          False         False  False    False
# 2          False         False  False    False
# 3          False         False  False    False
# 4          False         False  False    False
# ...          ...           ...    ...      ...
# 691395     False         False  False    False
# 691396     False         False  False    False
# 691397     False         False  False    False
# 691398     False         False  False    False
# 691399     False         False  False    False
#
# [691400 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# video_id         0
# comment_text    26
# likes            0
# replies          0
# dtype: int64

# %%
df.dropna()
# Out:
#            video_id                                       comment_text likes  \
# 0       XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1       XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2       XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3       XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4       XpVt6Z1Gjjo                                         trending 😉     3
# ...             ...                                                ...   ...
# 691395  EoejGgUNmVU                                             Лучшая     1
# 691396  EoejGgUNmVU  qu'est ce que j'aimerais que tu viennes à Roan...     0
# 691397  EoejGgUNmVU                          Ven a mexico! 😍 te amo LP     0
# 691398  EoejGgUNmVU                                    Islığı yeter...     0
# 691399  EoejGgUNmVU  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...     0
#
#        replies
# 0            0
# ...

# %%
df.dropna()
# Out:
#            video_id                                       comment_text likes  \
# 0       XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1       XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2       XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3       XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4       XpVt6Z1Gjjo                                         trending 😉     3
# ...             ...                                                ...   ...
# 691395  EoejGgUNmVU                                             Лучшая     1
# 691396  EoejGgUNmVU  qu'est ce que j'aimerais que tu viennes à Roan...     0
# 691397  EoejGgUNmVU                          Ven a mexico! 😍 te amo LP     0
# 691398  EoejGgUNmVU                                    Islığı yeter...     0
# 691399  EoejGgUNmVU  Kocham tą piosenkę😍❤❤❤byłam zakochana po uszy ...     0
#
#        replies
# 0            0
# ...

# %%
df=pd.read_csv("UScomments.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_csv("UScomments.csv")
#
# File c:\Users\Hp elitebook\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
rows, columns = df.shape
print(f"Rows: {rows}, Columns: {columns}")
# Out:
# Rows: 691400, Columns: 4
